# %%
#Task 2.1
import csv
from typing import List, Dict

def parse_story_csv(filepath: str) -> List[Dict]:
    """
    Parse a story file into a list of records

    Args:
        filepath: File to read from
    Returns:
        List of story book records
    """
    with open(filepath, "r", encoding="utf-8") as f:
        reader = csv.DictReader(f)
        return [record for record in reader]


def merge(left: List[Dict], right: List[Dict], sortby) -> List[Dict]:
    """
    Helper function for mergesort
    """
    res = []
    while left and right:
        e = right.pop(0) if left[0][sortby] > right[0][sortby] else left.pop(0)
        res.append(e)
    return res + left + right

def merge_sort(arr: List[Dict], sortby: str) -> List[Dict]:
    """
    Sort list of story records in ascending order
    according to the specified sort key

    Params:
        arr: Unsorted list of story records 
        sortby: Sort key
    Returns:
        Sorted list
    """
    if len(arr) > 1:
        mid = len(arr) // 2
        left, right = arr[:mid], arr[mid:]

        left, right = merge_sort(left, sortby), merge_sort(right, sortby)
        return merge(left, right, sortby)
    else:
        return arr


story_records = parse_story_csv("../story.csv")

inp_to_sortby = {
    "B": "book_title",
    "S": "subject",
    "A": "author_name",
    "P": "published"
}
user_input = None
while user_input not in inp_to_sortby:
    user_input = input("What would you like to sort by (B, S, A or P)? ").strip()
sortby = inp_to_sortby[user_input]

sorted_arr = merge_sort(story_records, sortby)
for each in sorted_arr:
    print(each)
# Out:
# {'book_title': 'A Mother Like Her', 'subject': 'Roads Less Travelled', 'author_name': 'R. Thuraimanikam', 'published': '2010'}
# {'book_title': 'Air Sebelanga', 'subject': 'Under One Sky', 'author_name': 'Fehmida Zakeer', 'published': '2013'}
# {'book_title': 'An Ode to Darkness', 'subject': 'Under One Sky', 'author_name': 'Chi Zi Jian', 'published': '2013'}
# {'book_title': 'As Good As New', 'subject': 'Under One Sky', 'author_name': 'Dr Lau Wai Har', 'published': '2013'}
# {'book_title': 'Badang The Strongman of Singapura', 'subject': 'Bridges', 'author_name': 'retold by Kiran Shah', 'published': '2012'}
# {'book_title': 'Bagaimana Harimau Mendapat Jalur-jalurnya', 'subject': 'Under One Sky', 'author_name': 'Diceritakan kembali oleh Rob Cleveland', 'published': '2013'}
# {'book_title': 'Bond', 'subject': 'Under One Sky', 'author_name': 'Melanmai Ponnusamy', 'published': '2013'}
# {'book_title': 'Cassette Tapes', 'subject': 'Roads Less Travelled', 'author_name': 'Stefanie Sun', 'published': '2010'}
# {'book_title': 'Cekal-Tekal-Mekar: Karya Sepanjang Zaman', 'subject': 'Cekal-Tekal-Mekar: Karya Sepanjang Zaman', 'author_name': 'various authors', 'published': '2014'}
# {'book_title': 'Cows', 'subject': 'Roads Less Travelled', 'author_name': 'Ismail Wardi', 'published': '2010'}
# {'book_title': 'Dalam Lif', 'subject': 'Bridges', 'author_name': 'Basiran Haji Hamzah', 'published': '2012'}
# {'book_title': 'Doa Seribu Tahun', 'subject': 'Transition', 'author_name': 'Yiyun Li', 'published': '2011'}
# {'book_title': 'Dua Buah Peti Kayu', 'subject': 'Under One Sky', 'author_name': 'Zhou Can', 'published': '2013'}
# {'book_title': 'Encounter', 'subject': 'Under One Sky', 'author_name': 'Rasiah Halil', 'published': '2013'}
# {'book_title': 'Ever After', 'subject': 'Roads Less Travelled', 'author_name': 'Nurfa’izah Tubi', 'published': '2010'}
# {'book_title': 'Gajah Putih', 'subject': 'Under One Sky', 'author_name': 'Zakaria Ali', 'published': '2013'}
# {'book_title': 'Gapura', 'subject': 'Transition', 'author_name': 'Yazid Hussein', 'published': '2011'}
# {'book_title': 'God’s Own Child', 'subject': 'Under One Sky', 'author_name': 'Suriya Rethnna', 'published': '2013'}
# {'book_title': 'Grasshoppers', 'subject': 'Bridges', 'author_name': 'O Thiam Chin', 'published': '2012'}
# {'book_title': 'Gypsies', 'subject': 'Ties That Bind', 'author_name': 'Rama Kannabiran', 'published': '2007'}
# {'book_title': 'Haiwan Kurungan Kertas', 'subject': 'Under One Sky', 'author_name': 'Ken Liu', 'published': '2013'}
# {'book_title': 'Home', 'subject': 'Transition', 'author_name': 'Kanagalatha', 'published': '2011'}
# {'book_title': 'How Tiger got His Stripes', 'subject': 'Under One Sky', 'author_name': 'Told by Rob Cleveland', 'published': '2013'}
# {'book_title': 'Isteriku Zelga', 'subject': 'Transition', 'author_name': 'Fauzani Azima Mawi', 'published': '2011'}
# {'book_title': 'Janji', 'subject': 'Bridges', 'author_name': 'Peter Augustine Goh', 'published': '2012'}
# {'book_title': 'Jurukamera', 'subject': 'Transition', 'author_name': 'Indrajit', 'published': '2011'}
# {'book_title': 'Kurniaan Tuhan', 'subject': 'Under One Sky', 'author_name': 'Suriya Rethnna', 'published': '2013'}
# {'book_title': 'Lee', 'subject': 'Ties That Bind', 'author_name': 'Claire Tham', 'published': '2007'}
# {'book_title': 'Lemang Nan Sebatang', 'subject': 'Under One Sky', 'author_name': 'Nisah Haron', 'published': '2013'}
# {'book_title': 'Marriage Guardian', 'subject': 'Roads Less Travelled', 'author_name': 'Patimah Jaludin', 'published': '2010'}
# {'book_title': 'Miscalculation', 'subject': 'Under One Sky', 'author_name': 'Maalan', 'published': '2013'}
# {'book_title': 'Morning Dew', 'subject': 'Ties That Bind', 'author_name': 'Ma Ilangkannan', 'published': '2007'}
# {'book_title': 'My Cousin Tim', 'subject': 'Dreams and Choices', 'author_name': 'Simon Tay', 'published': '2009'}
# {'book_title': 'My Wife, Zelga', 'subject': 'Transition', 'author_name': 'Fauzani Azima Mawi', 'published': '2011'}
# {'book_title': 'Nazam Kegelapan', 'subject': 'Under One Sky', 'author_name': 'Chi Zi Jian', 'published': '2013'}
# {'book_title': 'No Looking Back', 'subject': 'Dreams and Choices', 'author_name': 'Robert Shearman', 'published': '2009'}
# {'book_title': 'Pelayaran', 'subject': 'Transition', 'author_name': 'Liau Hong Chi', 'published': '2011'}
# {'book_title': 'Perlumbaan Kerbau dan Kura-kura', 'subject': 'Under One Sky', 'author_name': 'Diceritakan kembali oleh Sylvia MendezVentura', 'published': '2013'}
# {'book_title': 'Pertalian', 'subject': 'Under One Sky', 'author_name': 'Melanmai Ponnusamy', 'published': '2013'}
# {'book_title': 'Pertemuan', 'subject': 'Under One Sky', 'author_name': 'Rasiah Halil', 'published': '2013'}
# {'book_title': 'Pot Of Water', 'subject': 'Under One Sky', 'author_name': 'Fehmida Zakeer', 'published': '2013'}
# {'book_title': 'Refugee', 'subject': 'Roads Less Travelled', 'author_name': 'Llayavan (S. Uthuman Ghani)', 'published': '2010'}
# {'book_title': 'Rumah Saya, Nyawa Saya', 'subject': 'Transition', 'author_name': 'Kanagalatha', 'published': '2011'}
# {'book_title': 'Salah Hitung', 'subject': 'Under One Sky', 'author_name': 'Maalan', 'published': '2013'}
# {'book_title': 'Salah Pimpin', 'subject': 'Bridges', 'author_name': 'Keris Mas', 'published': '2012'}
# {'book_title': 'Sang Kancil and Sang Buaya', 'subject': 'Bridges', 'author_name': 'retold by Margaret Read Macdonald', 'published': '2012'}
# {'book_title': 'Sebaik Yang Baru', 'subject': 'Under One Sky', 'author_name': 'Dr Lau Wai Har', 'published': '2013'}
# {'book_title': 'Set Sail', 'subject': 'Transition', 'author_name': 'Liau Hong Chi', 'published': '2011'}
# {'book_title': 'Singa Yang Sangat Lapar', 'subject': 'Under One Sky', 'author_name': 'Diceritakan kembali oleh Gita Wolf', 'published': '2013'}
# {'book_title': 'Singapoetry: An Anthology of Singapore Poems', 'subject': 'Singapoetry: An Anthology of Singapore Poems', 'author_name': 'various authors', 'published': '2015'}
# {'book_title': 'Tales from East Asia/ Kisah-kisah dari Asia Timur', 'subject': 'Tales from East Asia/ Kisah-kisah dari Asia Timur', 'author_name': 'various authors', 'published': '2014'}
# {'book_title': 'Tanjong Rhu', 'subject': 'Ties That Bind', 'author_name': 'Ho Minfong', 'published': '2007'}
# {'book_title': 'Teenagers', 'subject': 'Ties That Bind', 'author_name': 'Kamariah Amat', 'published': '2007'}
# {'book_title': 'Ten-A-City: Stories Built to Last', 'subject': 'Ten-A-City: Stories Built to Last', 'author_name': 'various authors', 'published': '2014'}
# {'book_title': 'The Carabao-Turtle Race', 'subject': 'Under One Sky', 'author_name': 'Told by Sylvia Mendez Ventura', 'published': '2013'}
# {'book_title': 'The Cat’s Tail', 'subject': 'Bridges', 'author_name': 'retold by Rosemarie Somaiah', 'published': '2012'}
# {'book_title': 'The Handover', 'subject': 'Bridges', 'author_name': 'Yong Shu Hoong', 'published': '2012'}
# {'book_title': 'The Lemang Soliloquy', 'subject': 'Under One Sky', 'author_name': 'Nisah Haron', 'published': '2013'}
# {'book_title': 'The Mother', 'subject': 'Roads Less Travelled', 'author_name': 'Catherine Lim', 'published': '2010'}
# {'book_title': 'The Paper Menagerie', 'subject': 'Under One Sky', 'author_name': 'Ken Liu', 'published': '2013'}
# {'book_title': 'The Photographer', 'subject': 'Transition', 'author_name': 'Indrajit', 'published': '2011'}
# {'book_title': 'The Stars', 'subject': 'Bridges', 'author_name': 'S. Rajaratnam', 'published': '2012'}
# {'book_title': 'The Three Tests', 'subject': 'Roads Less Travelled', 'author_name': 'Louis Cha', 'published': '2010'}
# {'book_title': 'The Very Hungry Lion', 'subject': 'Under One Sky', 'author_name': 'Told by Gita Wolf', 'published': '2013'}
# {'book_title': 'The White Elephant', 'subject': 'Under One Sky', 'author_name': 'Zakaria Ali', 'published': '2013'}
# {'book_title': 'Through The Gateway', 'subject': 'Transition', 'author_name': 'Yazid Hussein', 'published': '2011'}
# {'book_title': 'Two Wooden Trunk Boxes', 'subject': 'Under One Sky', 'author_name': 'Zhou Can', 'published': '2013'}
# {'book_title': 'Video', 'subject': 'Under One Sky', 'author_name': 'Alfian Sa’at', 'published': '2013'}
# {'book_title': 'Video', 'subject': 'Under One Sky', 'author_name': 'Alfian Sa’at', 'published': '2013'}
# {'book_title': 'Willow In The Wind', 'subject': 'Ties That Bind', 'author_name': 'Soon Ai Ling', 'published': '2007'}

# %%
#Task 2.2
def quick_sort(arr: List[Dict]) -> List[Dict]:
    """
    Sorts list of movie records in descending order
    according to book_title
    """
    if len(arr) > 1:
        pivot = arr.pop()
        lte_pivot, gt_pivot = [], []

        for record in arr:
            if record["book_title"] <= pivot["book_title"]:
                gt_pivot.append(record)
            else:
                lte_pivot.append(record)

        lte_pivot, gt_pivot = quick_sort(lte_pivot), quick_sort(gt_pivot)
        return lte_pivot + [pivot] + gt_pivot
    else:
        return arr

quick_sort(story_records)
# Out:
# [{'book_title': 'Video',
#   'subject': 'Under One Sky',
#   'author_name': 'Alfian Sa’at',
#   'published': '2013'},
#  {'book_title': 'Two Wooden Trunk Boxes',
#   'subject': 'Under One Sky',
#   'author_name': 'Zhou Can',
#   'published': '2013'},
#  {'book_title': 'Through The Gateway',
#   'subject': 'Transition',
#   'author_name': 'Yazid Hussein',
#   'published': '2011'},
#  {'book_title': 'The White Elephant',
#   'subject': 'Under One Sky',
#   'author_name': 'Zakaria Ali',
#   'published': '2013'},
#  {'book_title': 'The Very Hungry Lion',
#   'subject': 'Under One Sky',
#   'author_name': 'Told by Gita Wolf',
#   'published': '2013'},
#  {'book_title': 'The Three Tests',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Louis Cha',
#   'published': '2010'},
#  {'book_title': 'The Stars',
#   'subject': 'Bridges',
#   'author_name': 'S. Rajaratnam',
#   'published': '2012'},
#  {'book_title': 'The Photographer',
#   'subject': 'Transition',
#   'author_name': 'Indrajit',
#   'published': '2011'},
#  {'book_title': 'The Paper Menagerie',
#   'subject': 'Under One Sky',
#   'author_name': 'Ken Liu',
#   'published': '2013'},
#  {'book_title': 'The Mother',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Catherine Lim',
#   'published': '2010'},
#  {'book_title': 'The Lemang Soliloquy',
#   'subject': 'Under One Sky',
#   'author_name': 'Nisah Haron',
#   'published': '2013'},
#  {'book_title': 'The Handover',
#   'subject': 'Bridges',
#   'author_name': 'Yong Shu Hoong',
#   'published': '2012'},
#  {'book_title': 'The Cat’s Tail',
#   'subject': 'Bridges',
#   'author_name': 'retold by Rosemarie Somaiah',
#   'published': '2012'},
#  {'book_title': 'The Carabao-Turtle Race',
#   'subject': 'Under One Sky',
#   'author_name': 'Told by Sylvia Mendez Ventura',
#   'published': '2013'},
#  {'book_title': 'Ten-A-City: Stories Built to Last',
#   'subject': 'Ten-A-City: Stories Built to Last',
#   'author_name': 'various authors',
#   'published': '2014'},
#  {'book_title': 'Teenagers',
#   'subject': 'Ties That Bind',
#   'author_name': 'Kamariah Amat',
#   'published': '2007'},
#  {'book_title': 'Tanjong Rhu',
#   'subject': 'Ties That Bind',
#   'author_name': 'Ho Minfong',
#   'published': '2007'},
#  {'book_title': 'Tales from East Asia/ Kisah-kisah dari Asia Timur',
#   'subject': 'Tales from East Asia/ Kisah-kisah dari Asia Timur',
#   'author_name': 'various authors',
#   'published': '2014'},
#  {'book_title': 'Singapoetry: An Anthology of Singapore Poems',
#   'subject': 'Singapoetry: An Anthology of Singapore Poems',
#   'author_name': 'various authors',
#   'published': '2015'},
#  {'book_title': 'Singa Yang Sangat Lapar',
#   'subject': 'Under One Sky',
#   'author_name': 'Diceritakan kembali oleh Gita Wolf',
#   'published': '2013'},
#  {'book_title': 'Set Sail',
#   'subject': 'Transition',
#   'author_name': 'Liau Hong Chi',
#   'published': '2011'},
#  {'book_title': 'Sebaik Yang Baru',
#   'subject': 'Under One Sky',
#   'author_name': 'Dr Lau Wai Har',
#   'published': '2013'},
#  {'book_title': 'Sang Kancil and Sang Buaya',
#   'subject': 'Bridges',
#   'author_name': 'retold by Margaret Read Macdonald',
#   'published': '2012'},
#  {'book_title': 'Salah Pimpin',
#   'subject': 'Bridges',
#   'author_name': 'Keris Mas',
#   'published': '2012'},
#  {'book_title': 'Salah Hitung',
#   'subject': 'Under One Sky',
#   'author_name': 'Maalan',
#   'published': '2013'},
#  {'book_title': 'Rumah Saya, Nyawa Saya',
#   'subject': 'Transition',
#   'author_name': 'Kanagalatha',
#   'published': '2011'},
#  {'book_title': 'Refugee',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Llayavan (S. Uthuman Ghani)',
#   'published': '2010'},
#  {'book_title': 'Pot Of Water',
#   'subject': 'Under One Sky',
#   'author_name': 'Fehmida Zakeer',
#   'published': '2013'},
#  {'book_title': 'Pertemuan',
#   'subject': 'Under One Sky',
#   'author_name': 'Rasiah Halil',
#   'published': '2013'},
#  {'book_title': 'Pertalian',
#   'subject': 'Under One Sky',
#   'author_name': 'Melanmai Ponnusamy',
#   'published': '2013'},
#  {'book_title': 'Perlumbaan Kerbau dan Kura-kura',
#   'subject': 'Under One Sky',
#   'author_name': 'Diceritakan kembali oleh Sylvia MendezVentura',
#   'published': '2013'},
#  {'book_title': 'Pelayaran',
#   'subject': 'Transition',
#   'author_name': 'Liau Hong Chi',
#   'published': '2011'},
#  {'book_title': 'No Looking Back',
#   'subject': 'Dreams and Choices',
#   'author_name': 'Robert Shearman',
#   'published': '2009'},
#  {'book_title': 'Nazam Kegelapan',
#   'subject': 'Under One Sky',
#   'author_name': 'Chi Zi Jian',
#   'published': '2013'},
#  {'book_title': 'My Wife, Zelga',
#   'subject': 'Transition',
#   'author_name': 'Fauzani Azima Mawi',
#   'published': '2011'},
#  {'book_title': 'My Cousin Tim',
#   'subject': 'Dreams and Choices',
#   'author_name': 'Simon Tay',
#   'published': '2009'},
#  {'book_title': 'Morning Dew',
#   'subject': 'Ties That Bind',
#   'author_name': 'Ma Ilangkannan',
#   'published': '2007'},
#  {'book_title': 'Miscalculation',
#   'subject': 'Under One Sky',
#   'author_name': 'Maalan',
#   'published': '2013'},
#  {'book_title': 'Marriage Guardian',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Patimah Jaludin',
#   'published': '2010'},
#  {'book_title': 'Lemang Nan Sebatang',
#   'subject': 'Under One Sky',
#   'author_name': 'Nisah Haron',
#   'published': '2013'},
#  {'book_title': 'Lee',
#   'subject': 'Ties That Bind',
#   'author_name': 'Claire Tham',
#   'published': '2007'},
#  {'book_title': 'Kurniaan Tuhan',
#   'subject': 'Under One Sky',
#   'author_name': 'Suriya Rethnna',
#   'published': '2013'},
#  {'book_title': 'Jurukamera',
#   'subject': 'Transition',
#   'author_name': 'Indrajit',
#   'published': '2011'},
#  {'book_title': 'Janji',
#   'subject': 'Bridges',
#   'author_name': 'Peter Augustine Goh',
#   'published': '2012'},
#  {'book_title': 'Isteriku Zelga',
#   'subject': 'Transition',
#   'author_name': 'Fauzani Azima Mawi',
#   'published': '2011'},
#  {'book_title': 'How Tiger got His Stripes',
#   'subject': 'Under One Sky',
#   'author_name': 'Told by Rob Cleveland',
#   'published': '2013'},
#  {'book_title': 'Home',
#   'subject': 'Transition',
#   'author_name': 'Kanagalatha',
#   'published': '2011'},
#  {'book_title': 'Haiwan Kurungan Kertas',
#   'subject': 'Under One Sky',
#   'author_name': 'Ken Liu',
#   'published': '2013'},
#  {'book_title': 'Gypsies',
#   'subject': 'Ties That Bind',
#   'author_name': 'Rama Kannabiran',
#   'published': '2007'},
#  {'book_title': 'Grasshoppers',
#   'subject': 'Bridges',
#   'author_name': 'O Thiam Chin',
#   'published': '2012'},
#  {'book_title': 'God’s Own Child',
#   'subject': 'Under One Sky',
#   'author_name': 'Suriya Rethnna',
#   'published': '2013'},
#  {'book_title': 'Gapura',
#   'subject': 'Transition',
#   'author_name': 'Yazid Hussein',
#   'published': '2011'},
#  {'book_title': 'Gajah Putih',
#   'subject': 'Under One Sky',
#   'author_name': 'Zakaria Ali',
#   'published': '2013'},
#  {'book_title': 'Ever After',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Nurfa’izah Tubi',
#   'published': '2010'},
#  {'book_title': 'Encounter',
#   'subject': 'Under One Sky',
#   'author_name': 'Rasiah Halil',
#   'published': '2013'},
#  {'book_title': 'Dua Buah Peti Kayu',
#   'subject': 'Under One Sky',
#   'author_name': 'Zhou Can',
#   'published': '2013'},
#  {'book_title': 'Doa Seribu Tahun',
#   'subject': 'Transition',
#   'author_name': 'Yiyun Li',
#   'published': '2011'},
#  {'book_title': 'Dalam Lif',
#   'subject': 'Bridges',
#   'author_name': 'Basiran Haji Hamzah',
#   'published': '2012'},
#  {'book_title': 'Cows',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Ismail Wardi',
#   'published': '2010'},
#  {'book_title': 'Cekal-Tekal-Mekar: Karya Sepanjang Zaman',
#   'subject': 'Cekal-Tekal-Mekar: Karya Sepanjang Zaman',
#   'author_name': 'various authors',
#   'published': '2014'},
#  {'book_title': 'Cassette Tapes',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'Stefanie Sun',
#   'published': '2010'},
#  {'book_title': 'Bond',
#   'subject': 'Under One Sky',
#   'author_name': 'Melanmai Ponnusamy',
#   'published': '2013'},
#  {'book_title': 'Bagaimana Harimau Mendapat Jalur-jalurnya',
#   'subject': 'Under One Sky',
#   'author_name': 'Diceritakan kembali oleh Rob Cleveland',
#   'published': '2013'},
#  {'book_title': 'Badang The Strongman of Singapura',
#   'subject': 'Bridges',
#   'author_name': 'retold by Kiran Shah',
#   'published': '2012'},
#  {'book_title': 'As Good As New',
#   'subject': 'Under One Sky',
#   'author_name': 'Dr Lau Wai Har',
#   'published': '2013'},
#  {'book_title': 'An Ode to Darkness',
#   'subject': 'Under One Sky',
#   'author_name': 'Chi Zi Jian',
#   'published': '2013'},
#  {'book_title': 'Air Sebelanga',
#   'subject': 'Under One Sky',
#   'author_name': 'Fehmida Zakeer',
#   'published': '2013'},
#  {'book_title': 'A Mother Like Her',
#   'subject': 'Roads Less Travelled',
#   'author_name': 'R. Thuraimanikam',
#   'published': '2010'}]
